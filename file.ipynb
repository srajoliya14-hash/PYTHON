# %%
f = open("/content/shubham.txt")
print(f.read())
# Out:
# hello my name iis shubh jain
# from Jaipur

# %%
f = open("/content/shubham.txt")
print(f.read(5))
# Out:
# hello

# %%
f = open("/content/shubham.txt")
print(f.readline())
# Out:
# hello my name iis shubh jain

# %%
f = open("/content/shubham.txt")
print(f.readline(2))
# Out:
# he

# %%
f = open("/content/shubham.txt")
print(f.close())
# Out:
# None

# %%
#writing to a file

f = open("/content/shubham.txt","a")
print(f.write("i went to read java"))
# Out:
# 19

# %%
f = open("/content/shubham.txt")
print(f.read())
# Out:
# i went to read java
# i went to read javai went to read javai went to read java

# %%
f = open("/content/shubham.txt","w")
print("f.write(i am shubham jain)")
# Out:
# f.write(i am shubham jain)

# %%
f = open("/content/shubham.txt")
print(f.read())

# %%
f = open("/content/shubham.txt")
print(f.read())

# %%
f = open("/content/shubham.txt","r+")
print(f.write("abc"))
f.close()
# Out:
# 3

# %%
f = open("/content/shubham.txt")
