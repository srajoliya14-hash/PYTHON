# %%
# exception handling
#exception = erros


a = int( input("enter ur pin:"))
print(a)
# Out:
# enter ur pin:321601
# 321601

# %%
try:
    a = int(input("enter ur pin:"))
    print(a)
except:
  print("enter valus is not in integer feom plese reenter")
  a = input("enter ur number")
  if type(int(a)) == type(10):
    print("ur pin is",a)
  else:
    print("invalid input")
# Out:
# enter valus is not in integer feom plese reenter
# enter ur number6666
# ur pin is 6666
# enter ur pin:12234

# %%
b = 1000
try:
  print(b)
except:
  print("b in not yet initialised, plese enter b:")
  b = input("plese enter b ' s valus")
  print("this is the valus of b:",b)
# Out:
# 1000

# %%
# how to handle exception raised by divide by zero error

a = int(input("enter numeratior:"))
b = int(input("enter denomintor:"))
print("the division of a/b is =",a/b)
# Out:
# enter numeratior:10
# enter denomintor:19
# the division of a/b is = 0.5263157894736842

# %%
try:
  a = int(input("enter numeratior:"))
  b = int(input("enter denomintor:"))
  print("the division of a/b is =",a/b)
except:
  print("your cannot enter denominator as 0")
  b = int(input("enter denomintor:"))
  if b!=0:
    print("the division of a/b is=",a/b)
  else:
    b+=1
    print("theans goes to infinity")
# Out:
# enter numeratior:90
# enter denomintor:0
# your cannot enter denominator as 0
# enter denomintor:0
# theans goes to infinity

# %%
c = 1000
try:
  print(c)
except:
  print("c in not yet initialised, plese enter c:")
  c = input("plese enter c ' s valus")
  print("this is the valus of c:",c)
else:
  print("this is the valus block")
# Out:
# 1000
# this is the valus block

# %%
try:
  print(d)
except:
  print("d in not yet initialised, plese enter d:")
  d = input("plese enter d ' s valus")
  print("this is the valus of d:",d)
# Out:
# d in not yet initialised, plese enter d:
# plese enter d ' s valus600
# this is the valus of d: 600

# %%
try:
  print(e)
except:
  print("e in not yet initialised, plese enter e:")
  e = input("plese enter e ' s valus")
  print("this is the valus of e:",e)
else:
  print("this is the valus block")
finally:
  print("this is finally block")

  # the finally bolck always run no matter if the block throws an error or not run  /
  # finally hamesh chalega chaye error aye ya na aye
# Out:
# e in not yet initialised, plese enter e:
# plese enter e ' s valus10101010
# this is the valus of e: 10101010
# this is finally block
