# %%
# oops
# CLASS= BLUEPRANT OR TEMPLATE
class student:
    name = 'shubham'
    age = 19
# OBJECT = INSTANCE OFCLASS

student1 = student()
student2 = student()
print(student1.name)
print(student1.age)
print(student2.age)
# Out:
# shubham
# 19
# 19

# %%
class student:
    def __init__(self,name,age):
        self.name = name
        self.age = age

student1 = student('shubham',19)
print(student1.name,student1.age)
student2 = student('shubh',9)
print(student2.name,student2.age)
# Out:
# shubham 19
# shubh 9

# %%
class student:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def student_details(self):
        print(f"{self.name} is in age {self.age}")
        print(self.name,self.age)
student1 = student('shubham',19)
student1.student_details()
# Out:
# shubham is in age 19
# shubham 19

# %%
class student:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def student_details(self):
        print(f"{self.name} is in age {self.age}")
        print(self.name,self.age)
print(student1.age)
student1.age = 20  # value change
print(student1.age)
# Out:
# 19
# 20

# %%
#features in opps
#abstraction = hide unnecesary
#encapsulation= 
#inheritance=
#polymorphism=

# %%
#abstraction
 

class student:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def student_details(self):
        print(f"{self.name} is in age {self.age+1}")
       
student1 = student('shubham',19)
student2 = student('shubh',29)
student1.student_details()
student2.student_details()
# Out:
# shubham is in age 20
# shubh is in age 30

# %%
#encapsulation

class student:
    def __init__(self,name,age):
        self.name = name
        self.__age = age
    def get_age(self):
        return self.__age age
    def student_details(self):
        print(f"{self.name} is in age {self.age}")
       
student1 = student('shubham',19)
student2 = student('shubh',29)
print(student2.get__age())
# Out:
#   Cell In[54], line 8
#     return self.__age age
#                       ^
# SyntaxError: invalid syntax

# %%
#inheritance=


class student:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def student_details(self):
        print(f"{self.name} is in age {self.age}")
       
student1 = student('shubham',19)
student2 = student('shubh',29)
class graduatestudent(student):
    def __init__(self,name ,age):
        super().__init__(name,age,stream)
        self.stream = stream
grad_student1 =  graduatestudent('bs',77,'pcm')
print(student1.age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 17
#      15         super().__init__(name,age,stream)
#      16         self.stream = stream
# ---> 17 grad_student1 =  graduatestudent('bs',77,'pcm')
#      18 print(student1.age)
#
# TypeError: graduatestudent.__init__() takes 3 positional arguments but 4 were given
