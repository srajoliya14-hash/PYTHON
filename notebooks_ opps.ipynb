# %%
# oop in python== (object oriented programming )

a = 20
b = 10

sum = a+ b
print(sum)
# Out:
# 30

# %%
a = 20
b = 10

diff = a- b
print(diff)
# Out:
# 10

# %%
#create a class

class student:
    name = "shubh"

#create a object

s1 = student()
print(s1.name)

s2 = student
print(s2.name)
# Out:
# shubh
# shubh

# %%
class car:
    color = "blue"
    brand = "bmw"
car1 = car()
print(car1.color)
print(car1.brand)
# Out:
# blue
# bmw

# %%
class student:
    def __init__(self,name,age):        # self is obj reference
        self.name = name
        self.age = age
        #print("create a new student") 
        #print(self)
s1 = student("subh",19)
print(s1.name,s1.age)
s2 = student("jain",18)
print(s2.name,s2.age)
# Out:
# subh 19
# jain 18

# %%
# attributes --2type
# class.attr
# obj.attr

class student:
    college = "skt"
def __init__(self,name,age):
    self.name = name
    self.age = age
    print("create a new student")
s1 = student("shubh",19)
print(s1.name,s1.age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 11
#       9     self.age = age
#      10     print("create a new student")
# ---> 11 s1 = student("shubh",19)
#      12 print(s1.name,s1.age)
#
# TypeError: student() takes no arguments

# %%
#methods= function that belong to object

class student:
    def __init__(self,name):
        self.name = name
    def welcome(self):
        print("welcome student",self.name)
s1 = student("shubh")
s1.welcome()
# Out:
# welcome student shubh

# %%
class student():
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
    def get_avg(self):
        sum = 0
        for valus in marks:
            sum += valus
        print("hi",self.name,"your avg score is :",sum/3)
s1 = student("shubh",[99,88,90])
s1.get_avg()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 11
#       9         print("hi",self.name,"your avg score is :",sum/3)
#      10 s1 = student("shubh",[99,88,90])
# ---> 11 s1.get_avg()
#
# Cell In[49], line 7, in student.get_avg(self)
#       5 def get_avg(self):
#       6     sum = 0
# ----> 7     for valus in marks:
#       8         sum += valus
#       9     print("hi",self.name,"your avg score is :",sum/3)
#
# NameError: name 'marks' is not defined

# %%
# static methods = donot use "self "
@staticmethod

# %%
# IMP
# abstraction = unnecessan features ko hiding karta hai / only essential features ko show krta hai 

class car:
    def __init__(self):
        self.acc = False
        self.brk = False
        self.clutch = False
    def start(self):
        self.clutch = True
        self.acc = True
       
        print("car started")
car1 = car()
car1.start()
# Out:
# car started

# %%
# encapsulation =

# %%
class account:
    def __init__(self,balance,accno):
        self.balance = balance
        self.accno = accno
    def debit(self,amount):
        self.balance -= amount
        print("rs",amount)
        print("total balance=",self.get_balance())
    def credit(self,amount):
        self.balance += amount
        print("rs",amount)
        print("total balance=",self.get_balance())
    def get_balance(self):
        return self.balance
acc1 = account(10000,34457) 
acc1.debit(800)
acc1.credit(1000)
# Out:
# rs 800
# total balance= 9200
# rs 1000
# total balance= 10200

# %%
#del kepworld = use to delete object properties or object itself
# del.s1.name
#del.s1

class student:
    def __init__(self,name):
        self.name = name
s1 = student("shubh")
print(s1)
print(s1)
del s1.name
del s1
print(s1)  # show the error 
print(s1      # show the error
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 13
#      11 del s1.name
#      12 del s1
# ---> 13 print(s1)
#      14 print(s1)
#
# NameError: name 's1' is not defined

# %%
# private attributes & methods = 

class account:
    def __init__(self,accno,accpass):
        self.accno = accno
        self.__accpass = accpass
acc1 = account("12344","ehheyg")
print(acc1.accno)
print(acc1.__accpass)   # show the error
# Out:
# 12344
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 9
#       7 acc1 = account("12344","ehheyg")
#       8 print(acc1.accno)
# ----> 9 print(acc1.__accpass)
#
# AttributeError: 'account' object has no attribute '__accpass'

# %%
class person:
    __name = "shubh"
p1 = person()
print(p1.__name)   #this is a  private attributes  becuse donot show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 4
#       2     __name = "shubh"
#       3 p1 = person()
# ----> 4 print(p1.__name)
#
# AttributeError: 'person' object has no attribute '__name'

# %%
# inheritance = 1, single inheritance
 #               2,multi-levelinheritance
#                 3,multipleinheritance

class car:
     
    def start(self):
        print("car started")

    
    def stop(self):
        print("car stopped")


class toyotacar(car):
    def __init__(self, name):
        self.name = name


car1 = toyotacar("fortuner")
car2 = toyotacar("prius")

print(car1.name)
car1.start()
car1.stop()

print(car2.name)
car2.start()
# Out:
# fortuner
# car started
# car stopped
# prius
# car started

# %%
#                 3,multipleinheritance


class a:
    vara = "welcome to a"
class b:
    varb = "welcome to b"
class c(a,b):
    varc = "welcome to c"
c1 = c()
print(c1.varc)
print(c1.varb)
print(c1.vara)
# Out:
# welcome to c
# welcome to b
# welcome to a

# %%
#super method

class car:
    def __init__(self, type):
        self.type = type

    @staticmethod
    def start():
        print("car started")

    @staticmethod
    def stop():
        print("car stopped")


class toyotacar(car):
    def __init__(self, name, type):
        self.name = name
        super().__init__(type)


car1 = toyotacar("prius", "electric")

print(car1.type)
print(car1.name)
car1.start()
car1.stop()
# Out:
# electric
# prius
# car started
# car stopped

# %%
#class method
class person:
    name = "shubh"
    #def changename(self,name):
     #   person.name = name
    @classmethod
    def changename(cls,name):
        cls.name = name
p1 = person()
p1.changename("shubhjain")
print(p1.name)
print(person.name)
# Out:
# shubhjain
# shubhjain
