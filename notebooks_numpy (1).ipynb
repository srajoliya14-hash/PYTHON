# %%
 import numpy as np

# %% [raw]
# print(np._version_)

# %%
# 1.creating arrays

# %%
list1 = [1,2,3]
print(list1)
# Out:
# [1, 2, 3]

# %%
arr_list1 = np.array(list1)
print(arr_list1)
# Out:
# [1 2 3]

# %%
print(type(arr_list1))
# Out:
# <class 'numpy.ndarray'>

# %%
arr = [1,2,3]
arr1 = [4,5,6]
arr2 = np.array([arr,arr1])
print(arr2)
print(arr2.ndim)
# Out:
# [[1 2 3]
#  [4 5 6]]
# 2

# %%
arr = [1,2,3]
arr1 = [4,5,6]
arr3 = [7,8,9]
arr2 = np.array([[arr,arr1,arr3]])
print(arr2)
print(arr2.ndim)
# Out:
# [[[1 2 3]
#   [4 5 6]
#   [7 8 9]]]
# 3

# %%
# 3.numpy array attributes

# %%
arr1 = np.array([[1,2,3],[4,5,6]])
print(arr1)
print(arr1.ndim)
print(arr1.shape)
print(arr1.dtype)
print(arr1.size)
# Out:
# [[1 2 3]
#  [4 5 6]]
# 2
# (2, 3)
# int32
# 6

# %% [raw]
# arr1 = np.array([1,2,3])
# print(arr1)

# %%
arr1 = np.array([1,2,3])
print(arr1)
print(arr1.ndim)
print(arr1.size)
print(arr1.shape)
print(arr1.dtype)
# Out:
# [1 2 3]
# 1
# 3
# (3,)
# int32

# %%
arr1 = np.array([[[1,2,3],[11,22,33],[44,34,66]]])
print(arr1)
print(arr1.ndim)
print(arr1.size)
print(arr1.shape)
print(arr1.dtype)
# Out:
# [[[ 1  2  3]
#   [11 22 33]
#   [44 34 66]]]
# 3
# 9
# (1, 3, 3)
# int32

# %%
# 3. array initialization methods

# %%
# zero array

arr = np.zeros((2,3))
print(arr)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
 #one array
arr = np.ones((1,3))
print(arr)
# Out:
# [[1. 1. 1.]]

# %%
# full array
arr = np.full((3,2),7)
print(arr)
# Out:
# [[7 7]
#  [7 7]
#  [7 7]]

# %%
# identity metrix
arr = np.eye(3)
print(arr)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
# iempty array
print(np.empty(2))
# Out:
# [1.63777334e-307 9.83366805e-308]

# %%
# evenly spaced array
print(np.arange(1,4,2))
print(np.arange(1,4,1))
print(np.arange(1,3,1))
# Out:
# [1 3]
# [1 2 3]
# [1 2]

# %%
# specific values between a range
print(np.linspace(1,10,4))
# Out:
# [ 1.  4.  7. 10.]

# %%
# random values array -- float
arr = np.random.rand(3,2)
print(arr)
# Out:
# [[0.53080028 0.29673441]
#  [0.73094222 0.19315647]
#  [0.619925   0.30856684]]

# %%
# random values array -- int
arr = np.random.randint(1,100,(3,3))
print(arr)
# Out:
# [[38 55  3]
#  [99  1 60]
#  [98 94 82]]

# %%
# ARRA INDEXING and slicing

# %%
a = np.array([1,3,5,7,9])
print(a)
# Out:
# [1 3 5 7 9]

# %%
# indexing
print(a[0])
print(a[4])
print(a[-1])
# Out:
# 1
# 9
# [3 5 7]
# 9

# %%
#slicing
print(a[1:4:1])
print(a[1:7:2])
print(a[1:4])
# Out:
# [3 5 7]
# [3 7]
# [3 5 7]

# %%
arr1 = np.array([[1,2,3],[4,5,6]])
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr1[0][0]  )
print(arr1[1][0]  )
# Out:
# 1
# 4

# %%
print(arr1[1:]  )
print(arr1[0:]  )
# Out:
# [[4 5 6]]
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr1[:,0]  )
# Out:
# [1 4]

# %%
arr = ([[1,2,3],[4,5,6],[7,8,9]])
print(arr)
print(arr[2][2])
print(arr[1][2])
print(arr[:2])
print(arr[2:])
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# 9
# 6
# [[1, 2, 3], [4, 5, 6]]
# [[7, 8, 9]]

# %%
# array reshaping and flattenung

# %%
arr = np.array([1,2,3,4,5,6])
print(arr)
# Out:
# [1 2 3 4 5 6]

# %%
reshape = arr.reshape((6,1))
print(reshape)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [6]]

# %%
reshape1 = arr.reshape((2,3))
print(reshape1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(reshape1.flatten())
# Out:
# [1 2 3 4 5 6]

# %%
# array stacking and splitting

# %%
a =  np.array([1,2,3])
b =  np.array([4,5,6])
print(np.vstack((a,b)))
print(np.hstack((a,b)))
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3 4 5 6]

# %%
c = np.array([[1,2,3],[4,5,6]])
print(c)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(np.hsplit(c,3))
print(np.vsplit(c,2))
# Out:
# [array([[1],
#        [4]]), array([[2],
#        [5]]), array([[3],
#        [6]])]
# [array([[1, 2, 3]]), array([[4, 5, 6]])]

# %%
# methematical oprations on array

# %%
a = np.array([10,20,40,-30])
print(a)
# Out:
# [ 10  20  40 -30]

# %%
print(a+10)
print(a-30)
print(a*2)
# Out:
# [ 20  30  50 -20]
# [-20 -10  10 -60]
# [ 20  40  80 -60]

# %%
print(np.square(a))
# Out:
# [ 100  400 1600  900]

# %%
# methematical oprations on muliple array

# %%
a = np.array([1,2,4])
b = np.array([5,6,7])
print(a)
print(b)
# Out:
# [1 2 4]
# [5 6 7]

# %%
print(np.add(a,b))
print(np.subtract(a,b))
print(np.multiply(a,b))
print(np.divide(a,b))
# Out:
# [ 6  8 11]
# [-4 -4 -3]
# [ 5 12 28]
# [0.2        0.33333333 0.57142857]

# %%
print(np.dot(a,b))
# Out:
# 45

# %%
print(a.T)
# Out:
# [1 2 4]

# %%
t = np.array([[1,2,3],[4,5,6]])
print(t)
print(t.T)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
# statistical function

# %%
a = np.array([[1,2,3],[4,5,6]])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(np.sum(a))
print(np.median(a))
print(np.min(a))
print(np.std(a))
# Out:
# 21
# 3.5
# 1
# 1.707825127659933

# %%
# array comparison

# %%
a = np.array([1,2,4])
b = np.array([5,6,7])
print(a)
print(b)
# Out:
# [1 2 4]
# [5 6 7]

# %%
print(a==b)
print(np.array_equal(a,b))
# Out:
# [False False False]
# False

# %%
# broadcasting

# %%
a = np.array([1,2,4])
b = np.array([5])
print(a+b)
# Out:
# [6 7 9]

# %%
# hanndling with nan

# %%
data = np.array([1,2,np.nan, 4, np.inf])
print(data)
# Out:
# [ 1.  2. nan  4. inf]

# %%
print(np.isnan(data))
# Out:
# [False False  True False False]

# %%
print(np.nan_to_num(data))
# Out:
# [1.00000000e+000 2.00000000e+000 0.00000000e+000 4.00000000e+000
#  1.79769313e+308]

# %%
# save and load array

# %%
arr = np.array([1,0,0,8])
print(arr)
np.save('my_array.npy',arr)
# Out:
# [1 0 0 8]

# %%
loaded_arr = np.load('my_array.npy')
print(loaded_arr)
# Out:
# [1 0 0 8]
